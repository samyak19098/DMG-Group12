# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import operator
import seaborn as sb
import plotly.express as px

# %%
banking_file = pd.read_csv("../data/banking.csv")
banking_file
# Out:
#        age          job  marital            education  default housing loan  \
# 0       44  blue-collar  married             basic.4y  unknown     yes   no
# 1       53   technician  married              unknown       no      no   no
# 2       28   management   single    university.degree       no     yes   no
# 3       39     services  married          high.school       no      no   no
# 4       55      retired  married             basic.4y       no     yes   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   59      retired  married          high.school  unknown      no  yes
# 41184   31    housemaid  married             basic.4y  unknown      no   no
# 41185   42       admin.   single    university.degree  unknown     yes  yes
# 41186   48   technician  married  professional.course       no      no  yes
# 41187   25      student   single          high.school       no      no   no
#
# ...

# %%
Y_banking = list(banking_file['y'])
unique, counts = np.unique(Y_banking, return_counts=True)
print(unique, counts)
# Out:
# [0 1] [36548  4640]

# %%
banking_file.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
columns = banking_file.columns
for i in range(len(columns)):
    
    print("Column name", columns[i])
    vals = banking_file[columns[i]]

    unique, counts = np.unique(vals, return_counts=True)
    d = dict(zip(unique, counts))
    print(d)
# Out:
# Column name age
# {17: 5, 18: 28, 19: 42, 20: 65, 21: 102, 22: 137, 23: 226, 24: 463, 25: 598, 26: 698, 27: 851, 28: 1001, 29: 1453, 30: 1714, 31: 1947, 32: 1846, 33: 1833, 34: 1745, 35: 1759, 36: 1780, 37: 1475, 38: 1407, 39: 1432, 40: 1161, 41: 1278, 42: 1142, 43: 1055, 44: 1011, 45: 1103, 46: 1030, 47: 928, 48: 979, 49: 839, 50: 875, 51: 754, 52: 779, 53: 733, 54: 684, 55: 648, 56: 704, 57: 646, 58: 576, 59: 463, 60: 283, 61: 73, 62: 62, 63: 55, 64: 57, 65: 44, 66: 57, 67: 26, 68: 33, 69: 34, 70: 47, 71: 53, 72: 34, 73: 34, 74: 32, 75: 24, 76: 34, 77: 20, 78: 27, 79: 14, 80: 31, 81: 20, 82: 17, 83: 17, 84: 7, 85: 15, 86: 8, 87: 1, 88: 22, 89: 2, 91: 2, 92: 4, 94: 1, 95: 1, 98: 2}
# Column name job
# {'admin.': 10422, 'blue-collar': 9254, 'entrepreneur': 1456, 'housemaid': 1060, 'management': 2924, 'retired': 1720, 'self-employed': 1421, 'services': 3969, 'student': 875, 'technician': 6743, 'unemployed': 1014, 'unknown': 330}
# Column name marital
# ...

# %%
cleanup_cols = {"job": {'admin.': 1, 'blue-collar': 2, 'entrepreneur': 3, 'housemaid': 4, 'management': 5, 'retired': 6, 'self-employed': 7, 'services': 8, 'student': 9, 'technician': 10, 'unemployed': 11, 'unknown': 12}, 
                "education": {'basic.4y': 1, 'basic.6y': 2, 'basic.9y': 3, 'high.school': 4, 'illiterate': 5, 'professional.course': 6, 'university.degree': 7, 'unknown': 8}, 
                "marital": {'divorced': 3, 'married': 2, 'single': 1, 'unknown': 4}, 
                "housing": {'no': 1, 'unknown': 3, 'yes': 2},
                 "loan": {'no':1, 'unknown': 3, 'yes': 2}, 
                 "contact":{'cellular': 1, 'telephone': 2}, 
                 "month": {'apr': 2 , 'aug': 6, 'dec': 10, 'jul': 5, 'jun': 4, 'mar': 1 , 'may': 3 , 'nov': 9, 'oct': 8, 'sep': 7}, 
                 "day_of_week": {'fri': 5, 'mon': 1, 'thu': 4, 'tue': 2, 'wed': 3},
                 "poutcome": {'failure': 2, 'nonexistent': 3, 'success': 1}}

# %%
banking_file = banking_file.replace(cleanup_cols)
banking_file.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   44    2        2          1  unknown        2     1        1      6
# 1   53   10        2          8       no        1     1        1      9
# 2   28    5        1          7       no        2     1        1      4
# 3   39    8        2          4       no        1     1        1      2
# 4   55    6        2          1       no        2     1        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp_var_rate  \
# 0            4  ...         1    999         0         3           1.4
# 1            5  ...         1    999         0         3          -0.1
# 2            4  ...         3      6         2         1          -1.7
# 3            5  ...         2    999         0         3          -1.8
# 4            5  ...         1      3         1         1          -2.9
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
banking_file = banking_file.drop(["default"], axis=1)
banking_file.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx',
#        'euribor3m', 'nr_employed', 'y'],
#       dtype='object')

# %%
banking_file
# Out:
#        age  job  marital  education  housing  loan  contact  month  \
# 0       44    2        2          1        2     1        1      6
# 1       53   10        2          8        1     1        1      9
# 2       28    5        1          7        2     1        1      4
# 3       39    8        2          4        1     1        1      2
# 4       55    6        2          1        2     1        1      6
# ...    ...  ...      ...        ...      ...   ...      ...    ...
# 41183   59    6        2          4        1     2        2      4
# 41184   31    4        2          1        1     1        2      3
# 41185   42    1        1          7        2     2        2      3
# 41186   48   10        2          6        1     2        2      8
# 41187   25    9        1          4        1     1        2      3
#
#        day_of_week  duration  campaign  pdays  previous  poutcome  \
# 0                4       210         1    999         0         3
# ...

# %%
banking_file.to_csv('../data/pre-processed_banking.csv')
